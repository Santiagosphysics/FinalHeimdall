# %%
from utils import get_data_crypto, models, meassures

time = 'S'
start_time = '2025-04-05'
end_time = '2025-04-15 06:00:00'
crypto = "ETHUSDT"

data = get_data_crypto().download_data(start_time=start_time, end_time=end_time, crypto=crypto, time=time)
df_prophet, predict_prophet = models().XGBoost_model(data=data, time=time)
test_1 = meassures().data_predict(model_pred=predict_prophet, crypto=crypto, time=time)
# Out:
# c:\Users\santi\OneDrive - Universidad Pedagogica Nacional\FinalHeimdall\utils.py:146: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df_pred = pd.date_range(start=df['ds'].max() + pd.Timedelta(seconds=1), periods=24*60*60, freq='S')
#                            ds  minute  hour  dayofweek  day            y
# 0     2025-04-15 06:00:01.999       0     6          1   15  1633.951538
# 1     2025-04-15 06:00:02.999       0     6          1   15  1633.951538
# 2     2025-04-15 06:00:03.999       0     6          1   15  1633.951538
# 3     2025-04-15 06:00:04.999       0     6          1   15  1633.951538
# 4     2025-04-15 06:00:05.999       0     6          1   15  1633.951538
# ...                       ...     ...   ...        ...  ...          ...
# 86395 2025-04-16 05:59:56.999      59     5          2   16  1637.839722
# 86396 2025-04-16 05:59:57.999      59     5          2   16  1637.839722
# 86397 2025-04-16 05:59:58.999      59     5          2   16  1637.839722
# 86398 2025-04-16 05:59:59.999      59     5          2   16  1637.839722
# 86399 2025-04-16 06:00:00.999       0     6          2   16  1630.786499
#
# [86400 rows x 6 columns]
# c:\Users\santi\OneDrive - Universidad Pedagogica Nacional\FinalHeimdall\utils.py:287: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   else:
# c:\Users\santi\OneDrive - Universidad Pedagogica Nacional\FinalHeimdall\utils.py:288: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   raise ValueError(f'Please write a correct option for the time {time}')

# %%
from utils import get_data_crypto, models, meassures

time = 'S'
start_time = '2025-04-10'
end_time = '2025-04-15 06:00:00'
crypto = "ETHUSDT"

data = get_data_crypto().download_data(start_time=start_time, end_time=end_time, crypto=crypto, time=time)
df_prophet, predict_prophet = models().XGBoost_model(data=data, time=time)
test_1 = meassures().data_predict(model_pred=predict_prophet, crypto=crypto, time=time)
# Out:
# c:\Users\santi\OneDrive - Universidad Pedagogica Nacional\FinalHeimdall\utils.py:146: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   df_pred = pd.date_range(start=df['ds'].max() + pd.Timedelta(seconds=1), periods=24*60*60, freq='S')
#                            ds  minute  hour  dayofweek  day            y
# 0     2025-04-15 06:00:01.999       0     6          1   15  1630.634399
# 1     2025-04-15 06:00:02.999       0     6          1   15  1630.634399
# 2     2025-04-15 06:00:03.999       0     6          1   15  1630.634399
# 3     2025-04-15 06:00:04.999       0     6          1   15  1630.634399
# 4     2025-04-15 06:00:05.999       0     6          1   15  1630.634399
# ...                       ...     ...   ...        ...  ...          ...
# 86395 2025-04-16 05:59:56.999      59     5          2   16  1640.514893
# 86396 2025-04-16 05:59:57.999      59     5          2   16  1640.514893
# 86397 2025-04-16 05:59:58.999      59     5          2   16  1640.514893
# 86398 2025-04-16 05:59:59.999      59     5          2   16  1640.514893
# 86399 2025-04-16 06:00:00.999       0     6          2   16  1630.634399
#
# [86400 rows x 6 columns]
# c:\Users\santi\OneDrive - Universidad Pedagogica Nacional\FinalHeimdall\utils.py:287: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   else:
# c:\Users\santi\OneDrive - Universidad Pedagogica Nacional\FinalHeimdall\utils.py:288: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   raise ValueError(f'Please write a correct option for the time {time}')
